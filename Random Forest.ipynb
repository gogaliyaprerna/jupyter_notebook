# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Loading Dataset**

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# **Getting to know the dataset**

# %%
df.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df.drop(["Id"], axis =1, inplace = True)

# %%
df["Species"] = df["Species"].str.replace("Iris-", "")

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **EDA**
#
#
# Steps in EDA
# 1.  Data Inspection:
#
# View the dataset structure:
# python
# Copy code
# print(data.head())  # First 5 rows
# print(data.info())  # Summary of data types and missing values
#
# Understand the dimensions and basic statistics:
# python
# Copy code
# print(data.shape)  # Rows and columns
# print(data.describe())  # Summary stats for numerical variables
#
# 2. Univariate Analysis:
#
# Analyze individual features to understand their distributions:
# Numerical Variables: Use histograms, box plots, or summary statistics.
# Categorical Variables: Use bar plots or pie charts.
#
# 3. Bivariate Analysis:
#
# Examine relationships between two variables:
# Scatter plots for numerical variables.
# Box plots for numerical-categorical relationships.
#
# 4. Multivariate Analysis:
#
# Explore relationships among multiple variables using pair plots, heatmaps, or dimensionality reduction (e.g., PCA).
# Detect Missing Values:
#
# Check for null or missing values and decide on handling strategies (e.g., imputation or removal).
#
# 5. Identify Outliers:
#
# Use box plots or statistical methods like Z-scores or IQR to detect and handle outliers.
#
# 6. Correlation Analysis:
#
# Identify relationships between numerical features:
# python
# Copy code
# import seaborn as sns
# sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
# Techniques and Tools for EDA
#
# 7. Visualization Tools:
#
# Histograms, box plots, scatter plots, bar plots, heatmaps.
# Libraries: matplotlib, seaborn, plotly, ggplot2.
#
# 8. Statistical Tools:
#
# Compute mean, median, standard deviation, skewness, and kurtosis.
# Libraries: pandas, numpy, scipy, statsmodels.
#
# 9. Data Transformation:
#
# Handle skewed data using logarithmic or other transformations.
# Scale or normalize data as needed for machine learning models.

# %%
sns.pairplot (df, hue = "Species" , height = 2.75)

# %% [markdown]
# **Hue**
#
#
#
# **What Does hue Do?**
# The hue parameter allows you to assign different colors to data points based on the levels of a categorical variable.
# It visually separates groups within your data, making it easier to identify patterns or differences.
#
# **How hue Works in Seaborn**
# 1. In Univariate Plots (e.g., histograms, box plots):
# Colors are assigned to different levels of the categorical variable.
# 2. In Bivariate/Multivariate Plots (e.g., scatter plots, pair plots):
# Each group is plotted with a unique color.

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa

# %%
df["Species_num"] = df["Species"]

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species  \
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa
#
#   Species_num
# 0      setosa
# 1      setosa
# 2      setosa
# 3      setosa
# 4      setosa

# %%
df["Species_num"] = df["Species_num"].str.replace("setosa", "1")
df["Species_num"] = df["Species_num"].str.replace("versicolor", "2")
df["Species_num"] = df["Species_num"].str.replace("virginica", "3")

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species  \
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa
#
#   Species_num
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
#  5   Species_num    150 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 7.2+ KB

# %%
df["Species_num"] = pd.to_numeric(df["Species_num"], downcast = "integer")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
#  5   Species_num    150 non-null    int8
# dtypes: float64(4), int8(1), object(1)
# memory usage: 6.1+ KB

# %%
numeric_df = df.select_dtypes(include=['number'])
plt.figure(figsize=(15, 9))
sns.heatmap(numeric_df.corr(), cmap='Spectral', annot=True)
plt.show()

# %%
df.drop(["PetalLengthCm" , "Species_num"], axis = 1 , inplace= True)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalWidthCm Species
# 0            5.1           3.5           0.2  setosa
# 1            4.9           3.0           0.2  setosa
# 2            4.7           3.2           0.2  setosa
# 3            4.6           3.1           0.2  setosa
# 4            5.0           3.6           0.2  setosa

# %% [markdown]
# **Decision Tree Modelling**

# %%
X = df.drop(["Species"],axis = 1)
y = df.Species

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier()

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt_model.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
print("Accuracy Score", accuracy_score(y_test, y_pred))
# Out:
# Accuracy Score 0.9736842105263158

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_scores = cross_val_score(estimator = dt_model, X=X_train , y =y_train, cv =10)
cv_scores.mean()
# Out:
# 0.8825757575757575

# %%
cv_scores
# Out:
# array([0.91666667, 1.        , 1.        , 1.        , 0.63636364,
#        0.90909091, 0.90909091, 0.90909091, 0.90909091, 0.63636364])

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[15  0  0]
#  [ 0 10  1]
#  [ 0  0 12]]

# %%
cnf_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(cnf_matrix,annot= True , cmap= "YlGnBu")
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
# Out:
# Text(0.5, 23.52222222222222, 'Predicted Label')

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      0.91      0.95        11
#    virginica       0.92      1.00      0.96        12
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
from sklearn import tree

# %%
list(df.columns [:-1])
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalWidthCm']

# %%
features = list(df.columns[:-1])
targets =["setosa" , "versicolor" , "virginica"]
print(features)
print(targets)
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalWidthCm']
# ['setosa', 'versicolor', 'virginica']

# %%
plt.figure(figsize = (20,20))
tree2 = tree.plot_tree(dt_model, filled = True , feature_names= features , class_names =targets)

# %% [markdown]
# **Hyperperameter Optimization with python**

# %%
from sklearn.model_selection import GridSearchCV

# %%
dt_model2 = DecisionTreeClassifier()

# %%
dt_params = {"criterion": ["gini", "entropy"],
              "max_depth" : np.arange(2, 14, 2),
              'max_features': ["auto", "sqrt", "log2"]}

# %%
dt_cv_model = GridSearchCV(estimator = dt_model2, param_grid = dt_params, cv = 10)

# %%
dt_cv_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([ 2,  4,  6,  8, 10, 12]),
#                          'max_features': ['auto', 'sqrt', 'log2']})

# %%
dt_cv_model.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt'}

# %%
dt_tuned= DecisionTreeClassifier(criterion = "gini" ,max_depth = 6, max_features = 'sqrt' )

# %%
dt_tuned.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=6, max_features='sqrt')

# %%
y_pred = dt_tuned.predict(X_test)

# %%
print("Accuracy Score:", accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score: 0.9473684210526315

# %%
cv_scores = cross_val_score(estimator = dt_tuned, X=X_train , y =y_train, cv =10)
cv_scores.mean()
# Out:
# 0.8946969696969695

# %%
plt.figure(figsize = (20,20))
tree2 = tree.plot_tree(dt_tuned, filled = True , feature_names= features , class_names =targets)

# %% [markdown]
# **Random forest Modelling**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()
rf_model.fit(X_train , y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf_model.predict(X_test)

# %%
print("Accuracy Score:", accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score: 0.9473684210526315

# %%
cv_scores = cross_val_score(estimator = rf_model, X=X_train , y =y_train, cv =10)
cv_scores.mean()
# Out:
# 0.9098484848484848

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[15  0  0]
#  [ 0  9  2]
#  [ 0  0 12]]

# %%
cnf_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(cnf_matrix,annot= True , cmap= "YlGnBu")
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
# Out:
# Text(0.5, 23.52222222222222, 'Predicted Label')

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      0.82      0.90        11
#    virginica       0.86      1.00      0.92        12
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.94      0.94        38
# weighted avg       0.95      0.95      0.95        38

# %%
rf_model.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1563167385),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1846608793),
#  DecisionTreeClassifier(max_features='sqrt', random_state=560669546),
#  DecisionTreeClassifier(max_features='sqrt', random_state=928726567),
#  DecisionTreeClassifier(max_features='sqrt', random_state=790918211),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1450576874),
#  DecisionTreeClassifier(max_features='sqrt', random_state=295666144),
#  DecisionTreeClassifier(max_features='sqrt', random_state=655697055),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1774681515),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1739953057),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1840231565),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1663699777),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2131793024),
# ...

# %%
plt.figure(figsize = (20,20))
tree2 = tree.plot_tree(rf_model.estimators_[0], filled = True , feature_names= features , class_names =targets)

# %% [markdown]
# **Hyperperameter Optimization**

# %%
rf_model2 = RandomForestClassifier()

# %%
rf_params = {"n_estimators":[50,100,300],
            "max_depth": [3,5,7],
            "max_features" : [2,4,6,8],
            "min_samples_split": [2,4,6]}

# %%
rf_cv_model = GridSearchCV(estimator = rf_model2, param_grid = rf_params, cv = 5, n_jobs = -1)

# %%
rf_cv_model.fit(X_train , y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7], 'max_features': [2, 4, 6, 8],
#                          'min_samples_split': [2, 4, 6],
#                          'n_estimators': [50, 100, 300]})

# %%
rf_cv_model.best_params_
# Out:
# {'max_depth': 3, 'max_features': 2, 'min_samples_split': 2, 'n_estimators': 50}

# %%
rf_tuned = RandomForestClassifier(max_depth =3,
                                 max_features = 2,
                                 min_samples_split =2,
                                 n_estimators =50)

# %%
rf_tuned.fit(X_train , y_train)
# Out:
# RandomForestClassifier(max_depth=3, max_features=2, n_estimators=50)

# %%
y_pred = rf_tuned.predict(X_test)

# %%
print("Accuracy Score:", accuracy_score(y_test,y_pred))
# Out:
# Accuracy Score: 1.0

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]

# %%
cnf_matrix = confusion_matrix(y_test,y_pred)
sns.heatmap(cnf_matrix,annot= True , cmap= "YlGnBu")
plt.ylabel("Actual Label")
plt.xlabel("Predicted Label")
# Out:
# Text(0.5, 23.52222222222222, 'Predicted Label')

# %%
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        15
#   versicolor       1.00      1.00      1.00        11
#    virginica       1.00      1.00      1.00        12
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38

# %%
rf_tuned.feature_importances_
# Out:
# array([0.18864686, 0.03976663, 0.77158651])

# %%
X_train.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalWidthCm'], dtype='object')

# %%
best_features = pd.Series(rf_tuned.feature_importances_,
                         index = X_train.columns).sort_values(ascending = False)

# %%
best_features
# Out:
# PetalWidthCm     0.771587
# SepalLengthCm    0.188647
# SepalWidthCm     0.039767
# dtype: float64

# %%
sns.barplot(x= best_features,y = best_features.index , hue = best_features )
plt.title("Features Importance")
plt.show()
