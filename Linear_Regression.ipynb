# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# Loading Dataset

# %%
df = sns.load_dataset ("mpg")

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df.drop(["name"],axis = 1, inplace = True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %% [markdown]
# Summery of dataset

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# Data Preprocessing

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin
# 32           71     usa
# 126          74     usa
# 330          80  europe
# 336          80     usa
# 354          81  europe
# 374          82     usa

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum().any()
# Out:
# False

# %%
df.shape
# Out:
# (392, 8)

# %% [markdown]
# Univariate Analysis

# %%
df.cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
df.cylinders.value_counts()
# Out:
# cylinders
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: count, dtype: int64

# %%
plt.figure(figsize =(15,8))
sns.countplot (x="cylinders",data = df , palette = "cubehelix")
plt.show()

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
df["model_year"]= (1900 + df.model_year)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0        1970    usa
# 1        1970    usa
# 2        1970    usa
# 3        1970    usa
# 4        1970    usa

# %%
plt.figure(figsize =(15,8))
sns.countplot (x="model_year",data = df , palette = "cubehelix")
plt.show()

# %%
plt.figure(figsize =(15,8))
sns.countplot (x="origin",data = df , palette = "cubehelix")
plt.show()

# %%
sns.distplot(df["horsepower"])
# Out:
# <Axes: xlabel='horsepower', ylabel='Density'>

# %%
sns.distplot(df["displacement"])
# Out:
# <Axes: xlabel='displacement', ylabel='Density'>

# %% [markdown]
# ** Bivariate Analysis**

# %%
plt.figure(figsize = (15,8))
sns.boxplot (x = "cylinders" , y = "mpg" , data= df ,palette = "deep" )
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.boxplot (x = "model_year" , y = "mpg" , data= df ,palette = "deep" )
plt.show()

# %% [markdown]
# MULTIVARIATE analysis

# %%
sns.lmplot(x="horsepower", y="mpg", hue="origin", data=df, palette="rainbow")

plt.show()

# %%
graph = sns.lmplot(x="horsepower", y="mpg", hue="origin", data=df, palette="rainbow")
graph.set(xlim = (0,250))
graph.set(ylim = (0,50))


plt.show()

# %%
graph = sns.lmplot(x="acceleration", y="mpg", hue="origin", data=df, palette="rainbow")
graph.set(xlim = (0,25))
graph.set(ylim = (5,50))


plt.show()

# %%
graph = sns.lmplot(x="weight", y="mpg", hue="origin", data=df, palette="rainbow")
graph.set(xlim = (1500,5500))
graph.set(ylim = (0,50))


plt.show()

# %%
graph = sns.lmplot(x="displacement", y="mpg", hue="origin", data=df, palette="rainbow")
graph.set(xlim = (0,475))
graph.set(ylim = (0,50))
plt.show()

# %% [markdown]
# Heatmap of Correiation of matrix

# %%
plt.figure(figsize=(15, 8))
sns.heatmap(numeric_df.corr(), annot=True, linewidths=0.5, cmap="rainbow")
plt.show()

# %%
df.drop(["acceleration", "displacement"],axis = 1, inplace = True)

# %%
df.head()
# Out:
#     mpg  cylinders  horsepower  weight  model_year origin
# 0  18.0          8       130.0    3504        1970    usa
# 1  15.0          8       165.0    3693        1970    usa
# 2  18.0          8       150.0    3436        1970    usa
# 3  16.0          8       150.0    3433        1970    usa
# 4  17.0          8       140.0    3449        1970    usa

# %%
from datetime import datetime

# %%
today =datetime.today()

# %%
today
# Out:
# datetime.datetime(2024, 12, 9, 14, 41, 9, 377990)

# %%
this_year= today.year
this_year
# Out:
# 2024

# %%
df["age"] = this_year - df.model_year

# %%
df.drop(["model_year"],axis =1, inplace = True)

# %%
df.head()
# Out:
#     mpg  cylinders  horsepower  weight origin  age
# 0  18.0          8       130.0    3504    usa   54
# 1  15.0          8       165.0    3693    usa   54
# 2  18.0          8       150.0    3436    usa   54
# 3  16.0          8       150.0    3433    usa   54
# 4  17.0          8       140.0    3449    usa   54

# %%
df.origin.unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
df = pd.get_dummies(df, drop_first = True)

# %%
df.head()
# Out:
#     mpg  cylinders  horsepower  weight  age  origin_japan  origin_usa
# 0  18.0          8       130.0    3504   54         False        True
# 1  15.0          8       165.0    3693   54         False        True
# 2  18.0          8       150.0    3436   54         False        True
# 3  16.0          8       150.0    3433   54         False        True
# 4  17.0          8       140.0    3449   54         False        True

# %% [markdown]
# Modelling

# %%
x = df.drop(["mpg"],axis =1)
y = df["mpg"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train , y_test =train_test_split(x,y, test_size = 0.2,random_state = 42)

# %%
x_train
# Out:
#      cylinders  horsepower  weight  age  origin_japan  origin_usa
# 260          6       110.0    3620   46         False        True
# 184          4        92.0    2572   48         False        True
# 174          6        97.0    2984   49         False        True
# 64           8       150.0    4135   52         False        True
# 344          4        64.0    1875   43         False        True
# ..         ...         ...     ...  ...           ...         ...
# 72           8       150.0    3892   52         False        True
# 107          6       100.0    2789   51         False        True
# 272          4        85.0    2855   46         False        True
# 352          4        65.0    2380   43         False        True
# 103          8       150.0    4997   51         False        True
#
# [313 rows x 6 columns]

# %%
y_train
# Out:
# 260    18.6
# 184    25.0
# 174    18.0
# 64     15.0
# 344    39.0
#        ...
# 72     15.0
# 107    18.0
# 272    23.8
# 352    29.9
# 103    11.0
# Name: mpg, Length: 313, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lm_model = LinearRegression()

# %%
lm_model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lm_model.intercept_
# Out:
# 79.80442103966979

# %%
coef_param = pd.DataFrame (lm_model.coef_,index = x.columns, columns =["coefficiant"])
coef_param
# Out:
#               coefficiant
# cylinders        0.203056
# horsepower      -0.014143
# weight          -0.005729
# age             -0.779904
# origin_japan     0.401853
# origin_usa      -2.385047

# %%
y_pred =  lm_model.predict(x_test)

# %%
my_dict =  {"Actual": y_test , "pred": y_pred}
compare = pd.DataFrame(my_dict)

# %%
compare.sample(10)
# Out:
#      Actual       pred
# 58     25.0  24.365480
# 78     21.0  21.764759
# 57     24.0  26.069444
# 143    26.0  27.341789
# 43     13.0   8.115192
# 34     16.0  16.116050
# 74     13.0  11.908848
# 235    26.0  30.326294
# 304    37.3  32.342511
# 115    15.0  13.832570

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error , r2_score

# %%
def evaluation_metrics(actual , pred):
    MAE = mean_absolute_error(actual , pred)
    MSE = mean_squared_error(actual , pred)
    RMSE = np.sqrt(mean_squared_error(actual , pred))
    SCORE = r2_score(actual , pred)
    return print ("r2_score:",SCORE , "\n","mae:",MAE, "\n","mse:", MSE , "\n","rmse:", RMSE)

# %%
evaluation_metrics(y_test,y_pred)
# Out:
# r2_score: 0.7798249880881911
#  mae: 2.5188281576150864
#  mse: 11.237861022823042
#  rmse: 3.3522919059686673

# %%
pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in c:\users\dell3420\anaconda3\lib\site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\dell3420\anaconda3\lib\site-packages (from yellowbrick) (3.9.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\dell3420\anaconda3\lib\site-packages (from yellowbrick) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\dell3420\anaconda3\lib\site-packages (from yellowbrick) (1.5.1)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\dell3420\anaconda3\lib\site-packages (from yellowbrick) (1.26.4)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\dell3420\anaconda3\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell3420\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell3420\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell3420\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell3420\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\dell3420\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell3420\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell3420\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell3420\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell3420\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell3420\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from yellowbrick.regressor import PredictionError

visualizer = PredictionError(lm_model)
visualizer.fit(x_train, y_train)
visualizer.score(x_test , y_test)

visualizer.show()
# Out:
# <Axes: title={'center': 'Prediction Error for LinearRegression'}, xlabel='$y$', ylabel='$\\hat{y}$'>

# %%
from yellowbrick.regressor import ResidualsPlot

visualizer = ResidualsPlot(lm_model)
visualizer.fit(x_train, y_train)
visualizer.score(x_test , y_test)

visualizer.show()
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %% [markdown]
# K-fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
accuracies = cross_val_score(estimator = lm_model, X= x_train, y= y_train,cv =10)

# %%
accuracies
# Out:
# array([0.83385985, 0.8017547 , 0.83571526, 0.79337835, 0.74392253,
#        0.78022115, 0.85414984, 0.76313671, 0.81547906, 0.88691579])

# %%
accuracies.mean()
# Out:
# 0.8108533245510495

# %%
accuracies = cross_val_score(estimator = lm_model, X= x_train, y= y_train,cv =10 ,scoring = "neg_mean_squared_error")

# %%
accuracies.mean()
# Out:
# -11.790387919443372

# %%
-accuracies.mean()
# Out:
# 11.790387919443372
